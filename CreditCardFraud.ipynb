# %%
# Import Libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Get Dataset from Google Drive
df1 = pd.read_csv("/content/drive/MyDrive/Fraud/fraudTrain.csv")
df1 = df1.drop(df1.columns[0], axis=1)

df2 = pd.read_csv("/content/drive/MyDrive/Fraud/fraudTest.csv")
df2 = df2.drop(df2.columns[0], axis=1)

df = pd.concat([df1,df2])
df
# Out:
#        trans_date_trans_time            cc_num  ...  merch_long is_fraud
# 0        2019-01-01 00:00:18  2703186189652095  ...  -82.048315        0
# 1        2019-01-01 00:00:44      630423337322  ... -118.186462        0
# 2        2019-01-01 00:00:51    38859492057661  ... -112.154481        0
# 3        2019-01-01 00:01:16  3534093764340240  ... -112.561071        0
# 4        2019-01-01 00:03:06   375534208663984  ...  -78.632459        0
# ...                      ...               ...  ...         ...      ...
# 555714   2020-12-31 23:59:07    30560609640617  ...  -91.333331        0
# 555715   2020-12-31 23:59:09  3556613125071656  ...  -96.186633        0
# 555716   2020-12-31 23:59:15  6011724471098086  ... -119.715054        0
# 555717   2020-12-31 23:59:24     4079773899158  ... -117.080888        0
# 555718   2020-12-31 23:59:34  4170689372027579  ...  -97.036372        0
#
# [1852394 rows x 22 columns]

# %%
# Get data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1852394 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trans_date_trans_time  object
#  1   cc_num                 int64
#  2   merchant               object
#  3   category               object
#  4   amt                    float64
#  5   first                  object
#  6   last                   object
#  7   gender                 object
#  8   street                 object
#  9   city                   object
#  10  state                  object
#  11  zip                    int64
#  12  lat                    float64
#  13  long                   float64
#  14  city_pop               int64
#  15  job                    object
#  16  dob                    object
#  17  trans_num              object
#  18  unix_time              int64
#  19  merch_lat              float64
#  20  merch_long             float64
# ...

# %%
# Get number of unique values in each column
df.nunique()
# Out:
# trans_date_trans_time    1819551
# cc_num                       999
# merchant                     693
# category                      14
# amt                        60616
# first                        355
# last                         486
# gender                         2
# street                       999
# city                         906
# state                         51
# zip                          985
# lat                          983
# long                         983
# city_pop                     891
# job                          497
# dob                          984
# trans_num                1852394
# unix_time                1819583
# merch_lat                1754157
# merch_long               1809753
# is_fraud                       2
# dtype: int64

# %%
# Check null values
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
# Get hour and week from trans_date_trans_time column
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
df['trans_hour'] = df['trans_date_trans_time'].dt.hour
df['day_of_week'] = df['trans_date_trans_time'].dt.day_name()
df
# Out:
#        trans_date_trans_time            cc_num  ... trans_hour day_of_week
# 0        2019-01-01 00:00:18  2703186189652095  ...          0     Tuesday
# 1        2019-01-01 00:00:44      630423337322  ...          0     Tuesday
# 2        2019-01-01 00:00:51    38859492057661  ...          0     Tuesday
# 3        2019-01-01 00:01:16  3534093764340240  ...          0     Tuesday
# 4        2019-01-01 00:03:06   375534208663984  ...          0     Tuesday
# ...                      ...               ...  ...        ...         ...
# 555714   2020-12-31 23:59:07    30560609640617  ...         23    Thursday
# 555715   2020-12-31 23:59:09  3556613125071656  ...         23    Thursday
# 555716   2020-12-31 23:59:15  6011724471098086  ...         23    Thursday
# 555717   2020-12-31 23:59:24     4079773899158  ...         23    Thursday
# 555718   2020-12-31 23:59:34  4170689372027579  ...         23    Thursday
#
# [1852394 rows x 24 columns]

# %%
df_category = df['category'].value_counts()
df_category = pd.DataFrame({'Category':df_category.index, 'Count':df_category.values})
fig = px.bar(data_frame=df_category, x='Category', y='Count', title='Transactions per Category - All Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03e97025-0674-4eec-82c7-a3c2fcdc9db3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03e97025-0674-4eec-82c7-a3c2fcdc9db3")) {
#                     Plotly.newPlot(
#                         '03e97025-0674-4eec-82c7-a3c2fcdc9db3',
# ...

# %%
df_category_fraud = df[df['is_fraud'] == 1]
df_category = df_category_fraud['category'].value_counts()
df_category = pd.DataFrame({'Category':df_category.index, 'Count':df_category.values})
fig = px.bar(data_frame=df_category, x='Category', y='Count', title='Transactions per Category - Fraud Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b6a0ef2-a844-4a47-884f-a405481e2a2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b6a0ef2-a844-4a47-884f-a405481e2a2a")) {
#                     Plotly.newPlot(
#                         '0b6a0ef2-a844-4a47-884f-a405481e2a2a',
# ...

# %%
df_day = df['day_of_week'].value_counts()
df_day = pd.DataFrame({'Day':df_day.index, 'Count':df_day.values})
fig = px.bar(data_frame=df_day, x='Day', y='Count', title='Transactions per Day - All Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fd063c7-cc4f-42f2-9cf3-2074d94382a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fd063c7-cc4f-42f2-9cf3-2074d94382a2")) {
#                     Plotly.newPlot(
#                         '4fd063c7-cc4f-42f2-9cf3-2074d94382a2',
# ...

# %%
df_day_fraud = df[df['is_fraud'] == 1]
df_day = df_day_fraud['day_of_week'].value_counts()
df_day = pd.DataFrame({'Day':df_day.index, 'Count':df_day.values})
fig = px.bar(data_frame=df_day, x='Day', y='Count', title='Transactions per Day - Fraud Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f686e013-8b04-41c5-ab95-ad8995f26cfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f686e013-8b04-41c5-ab95-ad8995f26cfd")) {
#                     Plotly.newPlot(
#                         'f686e013-8b04-41c5-ab95-ad8995f26cfd',
# ...

# %%
df_hour = df['trans_hour'].value_counts()
df_hour = pd.DataFrame({'Hour':df_hour.index, 'Count':df_hour.values})
fig = px.bar(data_frame=df_hour, x='Hour', y='Count', title='Transactions per Hour - All Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d058cd0-6a2e-4308-8f79-0295a269487c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d058cd0-6a2e-4308-8f79-0295a269487c")) {
#                     Plotly.newPlot(
#                         '2d058cd0-6a2e-4308-8f79-0295a269487c',
# ...

# %%
df_hour_fraud = df[df['is_fraud'] == 1]
df_hour = df_hour_fraud['trans_hour'].value_counts()
df_hour = pd.DataFrame({'Hour':df_hour.index, 'Count':df_hour.values})
fig = px.bar(data_frame=df_hour, x='Hour', y='Count', title='Transactions per Hour - Fraud Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="644be59a-3a44-4610-8324-bcb9c2fa3036" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("644be59a-3a44-4610-8324-bcb9c2fa3036")) {
#                     Plotly.newPlot(
#                         '644be59a-3a44-4610-8324-bcb9c2fa3036',
# ...

# %%
# Get age from dob column and distance between the user and merchant
def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])
    a = np.sin((lat2-lat1)/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2
    return earth_radius * 2 * np.arcsin(np.sqrt(a))
df['dob'] = pd.to_datetime(df['dob'])
df['age'] = np.round((df['trans_date_trans_time'] - df['dob'])/np.timedelta64(1,'Y'))
df['dist'] = haversine(df['lat'], df['long'], df['merch_lat'], df['merch_long'])
df
# Out:
#        trans_date_trans_time            cc_num  ...   age        dist
# 0        2019-01-01 00:00:18  2703186189652095  ...  31.0   78.597568
# 1        2019-01-01 00:00:44      630423337322  ...  41.0   30.212176
# 2        2019-01-01 00:00:51    38859492057661  ...  57.0  108.206083
# 3        2019-01-01 00:01:16  3534093764340240  ...  52.0   95.673231
# 4        2019-01-01 00:03:06   375534208663984  ...  33.0   77.556744
# ...                      ...               ...  ...   ...         ...
# 555714   2020-12-31 23:59:07    30560609640617  ...  55.0   77.026148
# 555715   2020-12-31 23:59:09  3556613125071656  ...  21.0  100.074420
# 555716   2020-12-31 23:59:15  6011724471098086  ...  39.0   80.759302
# 555717   2020-12-31 23:59:24     4079773899158  ...  55.0   52.933240
# 555718   2020-12-31 23:59:34  4170689372027579  ...  28.0   72.438289
#
# [1852394 rows x 26 columns]

# %%
df_state = df['state'].value_counts()
df_state = pd.DataFrame({'State':df_state.index, 'Count':df_state.values})
fig = px.bar(data_frame=df_state, x='State', y='Count', title='Transactions per State - All Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b380ac17-29ba-457d-bfb4-d5f6b566c6ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b380ac17-29ba-457d-bfb4-d5f6b566c6ec")) {
#                     Plotly.newPlot(
#                         'b380ac17-29ba-457d-bfb4-d5f6b566c6ec',
# ...

# %%
df_state_fraud = df[df['is_fraud'] == 1]
df_state = df_state_fraud['state'].value_counts()
df_state = pd.DataFrame({'State':df_state.index, 'Count':df_state.values})
fig = px.bar(data_frame=df_state, x='State', y='Count', title='Transactions per State - Fraud Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd5c2c70-7b4e-43d9-bc76-a808d14300ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd5c2c70-7b4e-43d9-bc76-a808d14300ee")) {
#                     Plotly.newPlot(
#                         'dd5c2c70-7b4e-43d9-bc76-a808d14300ee',
# ...

# %%
df_gender = df['gender'].value_counts()
df_gender = pd.DataFrame({'Gender':df_gender.index, 'Count':df_gender.values})
fig = px.bar(data_frame=df_gender, x='Gender', y='Count', title='Transactions per Gender - All Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="58075772-72a0-4573-b6e4-9dde5701805d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58075772-72a0-4573-b6e4-9dde5701805d")) {
#                     Plotly.newPlot(
#                         '58075772-72a0-4573-b6e4-9dde5701805d',
# ...

# %%
df_gender_fraud = df[df['is_fraud'] == 1]
df_gender = df_gender_fraud['gender'].value_counts()
df_gender = pd.DataFrame({'Gender':df_gender.index, 'Count':df_gender.values})
fig = px.bar(data_frame=df_gender, x='Gender', y='Count', title='Transactions per Gender - Fraud Transaction')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a5efcbc4-a7ee-46e4-b2cb-1204a5defa71" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5efcbc4-a7ee-46e4-b2cb-1204a5defa71")) {
#                     Plotly.newPlot(
#                         'a5efcbc4-a7ee-46e4-b2cb-1204a5defa71',
# ...

# %%
# Apply one hot encoding to category, gender and day
category_onehot = pd.get_dummies(df.category, prefix='category', drop_first=True)
gender_onehot = pd.get_dummies(df.gender, prefix='gender', drop_first=True)
day_of_week_onehot = pd.get_dummies(df.day_of_week, prefix='week',drop_first=True)
df = pd.concat([df, category_onehot,gender_onehot,day_of_week_onehot], axis=1)
df
# Out:
#        trans_date_trans_time            cc_num  ... week_Tuesday week_Wednesday
# 0        2019-01-01 00:00:18  2703186189652095  ...            1              0
# 1        2019-01-01 00:00:44      630423337322  ...            1              0
# 2        2019-01-01 00:00:51    38859492057661  ...            1              0
# 3        2019-01-01 00:01:16  3534093764340240  ...            1              0
# 4        2019-01-01 00:03:06   375534208663984  ...            1              0
# ...                      ...               ...  ...          ...            ...
# 555714   2020-12-31 23:59:07    30560609640617  ...            0              0
# 555715   2020-12-31 23:59:09  3556613125071656  ...            0              0
# 555716   2020-12-31 23:59:15  6011724471098086  ...            0              0
# 555717   2020-12-31 23:59:24     4079773899158  ...            0              0
# 555718   2020-12-31 23:59:34  4170689372027579  ...            0              0
#
# ...

# %%
df_fraud = df['is_fraud'].value_counts()
df_fraud = pd.DataFrame({'Is Fraud?':df_fraud.index, 'Count':df_fraud.values})
fig = px.bar(data_frame=df_fraud, x='Is Fraud?', y='Count', title='Is Fraud Transaction? 0-Not Fraud, 1-Fraud')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f8c98b8-3290-468b-b0f2-ce7d4ad71f06" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f8c98b8-3290-468b-b0f2-ce7d4ad71f06")) {
#                     Plotly.newPlot(
#                         '1f8c98b8-3290-468b-b0f2-ce7d4ad71f06',
# ...

# %%
# Since it is a unbalanced dataset, apply random oversampling
count_notfraud = df[df['is_fraud'] == 0]['amt'].count()
df_fraud = df[df['is_fraud'] == 1]
df_notfraud = df[df['is_fraud'] == 0]
df = df_fraud.sample(count_notfraud, replace=True)
df = pd.concat([df_notfraud, df], axis=0)
df
# Out:
#        trans_date_trans_time               cc_num  ... week_Tuesday week_Wednesday
# 0        2019-01-01 00:00:18     2703186189652095  ...            1              0
# 1        2019-01-01 00:00:44         630423337322  ...            1              0
# 2        2019-01-01 00:00:51       38859492057661  ...            1              0
# 3        2019-01-01 00:01:16     3534093764340240  ...            1              0
# 4        2019-01-01 00:03:06      375534208663984  ...            1              0
# ...                      ...                  ...  ...          ...            ...
# 432157   2019-07-12 23:16:42     4610050989831291  ...            0              0
# 86078    2019-02-19 23:04:29  4599735407877245080  ...            1              0
# 884569   2019-12-22 23:50:34     4424338559877976  ...            0              0
# 45885    2019-01-28 05:19:38      373213026644490  ...            0              0
# ...

# %%
df_fraud = df['is_fraud'].value_counts()
df_fraud = pd.DataFrame({'Is Fraud?':df_fraud.index, 'Count':df_fraud.values})
fig = px.bar(data_frame=df_fraud, x='Is Fraud?', y='Count', title='Is Fraud Transaction? 0-Not Fraud, 1-Fraud')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2f742a12-51f3-437f-a364-4e810a87ccaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f742a12-51f3-437f-a364-4e810a87ccaa")) {
#                     Plotly.newPlot(
#                         '2f742a12-51f3-437f-a364-4e810a87ccaa',
# ...

# %%
# Remove useless and redundant columns
df = df.drop(['trans_date_trans_time', 'merchant', 'city', 'state', 'category', 'cc_num', 'first', 'last', 'dob', 'job', 'lat', 'long', 'merch_lat', 'merch_long', 'trans_num', 'unix_time', 'city_pop', 'zip', 'street', 'day_of_week', 'gender'], axis=1)
df
# Out:
#             amt  is_fraud  ...  week_Tuesday  week_Wednesday
# 0          4.97         0  ...             1               0
# 1        107.23         0  ...             1               0
# 2        220.11         0  ...             1               0
# 3         45.00         0  ...             1               0
# 4         41.96         0  ...             1               0
# ...         ...       ...  ...           ...             ...
# 432157   576.10         1  ...             0               0
# 86078   1042.38         1  ...             1               0
# 884569   589.11         1  ...             0               0
# 45885    306.20         1  ...             0               0
# 598566    10.34         1  ...             0               1
#
# [3685486 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3685486 entries, 0 to 598566
# Data columns (total 25 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   amt                      float64
#  1   is_fraud                 int64
#  2   trans_hour               int64
#  3   age                      float64
#  4   dist                     float64
#  5   category_food_dining     uint8
#  6   category_gas_transport   uint8
#  7   category_grocery_net     uint8
#  8   category_grocery_pos     uint8
#  9   category_health_fitness  uint8
#  10  category_home            uint8
#  11  category_kids_pets       uint8
#  12  category_misc_net        uint8
#  13  category_misc_pos        uint8
#  14  category_personal_care   uint8
#  15  category_shopping_net    uint8
#  16  category_shopping_pos    uint8
#  17  category_travel          uint8
#  18  gender_M                 uint8
#  19  week_Monday              uint8
#  20  week_Saturday            uint8
# ...

# %%
# Training data and test data split
from sklearn.model_selection import train_test_split
X = df.loc[:, df.columns != 'is_fraud']
y = df[['is_fraud']]
X_train, X_test, y_train, y_test = train_test_split(X, y , train_size=0.7, test_size=0.3, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2579840, 24)
# (2579840, 1)
# (1105646, 24)
# (1105646, 1)

# %% [markdown]
# # Random Forest Classifier

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV

# %%
# Find best hyperparameters using grid search

# rf = RandomForestClassifier()
# param_grid = [{'n_estimators': [5, 10, 20, 50, 100],
#                'max_depth' : [5, 10, 15, 20],
#                'criterion': ['gini','entropy']
# }]
# rf_grid = GridSearchCV(rf, param_grid= param_grid, verbose=2, cv = 3)
# best_rf = rf_grid.fit(X_train, y_train.values.ravel())
# best_rf.best_params_

# %%
rf_model = RandomForestClassifier(criterion = 'gini', n_estimators = 50, max_depth = 20,
                                random_state = 123)
rf_model.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=50, random_state=123)

# %% [markdown]
# ## Training Data

# %%
print("------ Predicting on Training Dataset ------")
pred_train = rf_model.predict(X_train)
# Out:
# ------ Predicting on Training Dataset ------

# %%
rf_mat = confusion_matrix(y_train, pred_train)
fig = ff.create_annotated_heatmap(rf_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Random Forest)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3e895c9f-e6db-4033-9e04-e98a333c79af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e895c9f-e6db-4033-9e04-e98a333c79af")) {
#                     Plotly.newPlot(
#                         '3e895c9f-e6db-4033-9e04-e98a333c79af',
# ...

# %%
print("Precision:", precision_score(y_train, pred_train))
print("Recall:", recall_score(y_train, pred_train))
print("F1 Score:", f1_score(y_train, pred_train))
# Out:
# Precision: 0.9975660424639353
# Recall: 0.9999069716240196
# F1 Score: 0.9987351353234851

# %%
print("------ Accuracy ------")
print("Random Forest: ", accuracy_score(y_train, pred_train, normalize=True))
# Out:
# ------ Accuracy ------
# Random Forest:  0.9987336423964277

# %% [markdown]
# ## Testing Data

# %%
print("------ Predicting on Test Dataset ------")
pred_test = rf_model.predict(X_test)
# Out:
# ------ Predicting on Test Dataset ------

# %%
rf_mat = confusion_matrix(y_test, pred_test)
fig = ff.create_annotated_heatmap(rf_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Random Forest)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d6c10e6-bbed-4b47-9ef0-c4d90b0aa3af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d6c10e6-bbed-4b47-9ef0-c4d90b0aa3af")) {
#                     Plotly.newPlot(
#                         '6d6c10e6-bbed-4b47-9ef0-c4d90b0aa3af',
# ...

# %%
print("Precision:", precision_score(y_test, pred_test))
print("Recall:", recall_score(y_test, pred_test))
print("F1 Score:", f1_score(y_test, pred_test))
# Out:
# Precision: 0.9969015456201418
# Recall: 0.999887846545131
# F1 Score: 0.9983924629995556

# %%
print("------ Accuracy ------")
print("Random Forest: ", accuracy_score(y_test, pred_test, normalize=True))
# Out:
# ------ Accuracy ------
# Random Forest:  0.9983900814546428

# %% [markdown]
# # Decision Tree Classifier

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Find best hyperparameters using grid search

# dt = DecisionTreeClassifier(max_depth=3)
# param_grid = [{
#                'max_depth' : [5, 10, 15, 20],
#                'criterion': ['gini','entropy']
# }]
# dt_grid = GridSearchCV(dt, param_grid= param_grid, verbose=2, cv = 3)
# best_dt = dt_grid.fit(X_train, y_train.values.ravel())
# best_dt.best_params_

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini', max_depth = 20, random_state=123)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=20, random_state=123)

# %% [markdown]
# ## Training Data

# %%
print("------ Predicting on Training Dataset ------")
pred_train = dt_model.predict(X_train)
# Out:
# ------ Predicting on Training Dataset ------

# %%
dt_mat = confusion_matrix(y_train, pred_train)
fig = ff.create_annotated_heatmap(dt_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Decision Tree)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="482da7a3-3e89-4535-933d-18d8c289ba61" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("482da7a3-3e89-4535-933d-18d8c289ba61")) {
#                     Plotly.newPlot(
#                         '482da7a3-3e89-4535-933d-18d8c289ba61',
# ...

# %%
print("Precision:", precision_score(y_train, pred_train))
print("Recall:", recall_score(y_train, pred_train))
print("F1 Score:", f1_score(y_train, pred_train))
# Out:
# Precision: 0.9927823062601833
# Recall: 1.0
# F1 Score: 0.9963780821833158

# %%
print("------ Accuracy ------")
print("Decision Tree: ", accuracy_score(y_train, pred_train, normalize=True))
# Out:
# ------ Accuracy ------
# Decision Tree:  0.9963648908459439

# %% [markdown]
# ## Testing Data

# %%
print("------ Predicting on Test Dataset ------")
pred_test = dt_model.predict(X_test)
# Out:
# ------ Predicting on Test Dataset ------

# %%
dt_mat = confusion_matrix(y_test, pred_test)
fig = ff.create_annotated_heatmap(dt_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Decision Tree)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="982a013e-dd53-45c0-8cc4-744917bcaa33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("982a013e-dd53-45c0-8cc4-744917bcaa33")) {
#                     Plotly.newPlot(
#                         '982a013e-dd53-45c0-8cc4-744917bcaa33',
# ...

# %%
print("Precision:", precision_score(y_test, pred_test))
print("Recall:", recall_score(y_test, pred_test))
print("F1 Score:", f1_score(y_test, pred_test))
# Out:
# Precision: 0.992089328849184
# Recall: 1.0
# F1 Score: 0.9960289576193926

# %%
print("------ Accuracy ------")
print("Decision Tree: ", accuracy_score(y_test, pred_test, normalize=True))
# Out:
# ------ Accuracy ------
# Decision Tree:  0.9960131904786885

# %% [markdown]
# # Neural Network

# %%
# Neural Network
from keras.models import Sequential
from keras.layers import Dense
 
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=24))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               3200
#
#  dense_1 (Dense)             (None, 1)                 129
#
# ...
# Total params: 3,329
# Trainable params: 3,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=100)
# Out:
# Epoch 1/20
# 25799/25799 [==============================] - 68s 3ms/step - loss: 0.1541 - accuracy: 0.9471 - val_loss: 0.1288 - val_accuracy: 0.9619
# Epoch 2/20
# 25799/25799 [==============================] - 58s 2ms/step - loss: 0.0930 - accuracy: 0.9668 - val_loss: 0.0744 - val_accuracy: 0.9729
# Epoch 3/20
# 25799/25799 [==============================] - 58s 2ms/step - loss: 0.0748 - accuracy: 0.9723 - val_loss: 0.0680 - val_accuracy: 0.9738
# Epoch 4/20
# 25799/25799 [==============================] - 66s 3ms/step - loss: 0.0667 - accuracy: 0.9749 - val_loss: 0.0743 - val_accuracy: 0.9724
# Epoch 5/20
# 25799/25799 [==============================] - 57s 2ms/step - loss: 0.0623 - accuracy: 0.9766 - val_loss: 0.0733 - val_accuracy: 0.9770
# Epoch 6/20
# 25799/25799 [==============================] - 67s 3ms/step - loss: 0.0597 - accuracy: 0.9776 - val_loss: 0.0587 - val_accuracy: 0.9774
# Epoch 7/20
# ...

# %% [markdown]
# ## Training Dataset

# %%
print("------ Predicting on Training Dataset ------")
pred_train = model.predict(X_train)
# Out:
# ------ Predicting on Training Dataset ------

# %%
nn_mat = confusion_matrix(y_train, np.round(pred_train))
fig = ff.create_annotated_heatmap(nn_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Neural Network)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="11c8b3a9-6918-441d-9018-7e473e465e6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11c8b3a9-6918-441d-9018-7e473e465e6c")) {
#                     Plotly.newPlot(
#                         '11c8b3a9-6918-441d-9018-7e473e465e6c',
# ...

# %%
print("Precision:", precision_score(y_train, np.round(pred_train)))
print("Recall:", recall_score(y_train, np.round(pred_train)))
print("F1 Score:", f1_score(y_train, np.round(pred_train)))
# Out:
# Precision: 0.9805920825681459
# Recall: 0.9806376940126162
# F1 Score: 0.9806148877599985

# %%
print("------ Accuracy ------")
print("Neural Network: ", accuracy_score(y_train, np.round(pred_train), normalize=True))
# Out:
# ------ Accuracy ------
# Neural Network:  0.9806143016621186

# %% [markdown]
# ## Testing Dataset

# %%
print("------ Predicting on Test Dataset ------")
pred_test = model.predict(X_test)
# Out:
# ------ Predicting on Test Dataset ------

# %%
nn_mat = confusion_matrix(y_test, np.round(pred_test))
fig = ff.create_annotated_heatmap(nn_mat[::-1], x=['Not Fraud', 'Fraud'], y=['Fraud', 'Not Fraud'])
fig.update_layout(title_text='<i><b>Confusion Matrix (Neural Network)</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03ae04b3-9573-48e0-88ee-5e145faa043f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03ae04b3-9573-48e0-88ee-5e145faa043f")) {
#                     Plotly.newPlot(
#                         '03ae04b3-9573-48e0-88ee-5e145faa043f',
# ...

# %%
print("Precision:", precision_score(y_test, np.round(pred_test)))
print("Recall:", recall_score(y_test, np.round(pred_test)))
print("F1 Score:", f1_score(y_test, np.round(pred_test)))
# Out:
# Precision: 0.9803364183131345
# Recall: 0.9806698093753052
# F1 Score: 0.9805030855042792

# %%
print("------ Accuracy ------")
print("Neural Network: ", accuracy_score(y_test, np.round(pred_test), normalize=True))
# Out:
# ------ Accuracy ------
# Neural Network:  0.9805000877315162

# %% [markdown]
# # Summary

# %%
sum_mat = [[98.03, 98.06, 98.05, 98.05], [99.20, 99.99, 99.61, 99.61], [99.69, 99.98, 99.83, 99.83]]
fig = ff.create_annotated_heatmap(sum_mat, x=['Precision', 'Reacll', 'F1 Score', 'Accuracy'], y=['Neural Network', 'Decision Tree', 'Random Forest'])
fig.update_layout(title_text='<i><b>Summaring Models Performance</b></i>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f9a6f15-d0bf-46ce-b4f1-e1d24fa1d422" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f9a6f15-d0bf-46ce-b4f1-e1d24fa1d422")) {
#                     Plotly.newPlot(
#                         '4f9a6f15-d0bf-46ce-b4f1-e1d24fa1d422',
# ...

# %%
# Random Forest model performs well. So use that model to deploy on web application
import pickle
file_name = "creditCardFraud.pkl"  

with open(file_name, 'wb') as file:  
    pickle.dump(rf_model, file)
